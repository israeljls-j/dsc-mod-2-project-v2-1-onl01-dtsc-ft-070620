# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Final Project Submission</a></span></li><li><span><a href="#Project-Summary" data-toc-modified-id="Project-Summary-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project Summary</a></span></li><li><span><a href="#Mission" data-toc-modified-id="Mission-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Mission</a></span></li><li><span><a href="#Import-packages" data-toc-modified-id="Import-packages-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import packages</a></span></li><li><span><a href="#Transform-the-data-and-provide-high-level-analysis" data-toc-modified-id="Transform-the-data-and-provide-high-level-analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Transform the data and provide high level analysis</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Review-column-names-to-ensure-that-they-represent-the-actual-data" data-toc-modified-id="Review-column-names-to-ensure-that-they-represent-the-actual-data-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Review column names to ensure that they represent the actual data</a></span></li><li><span><a href="#Check-datatypes---change-sqft_basement-from-'o'-to-int" data-toc-modified-id="Check-datatypes---change-sqft_basement-from-'o'-to-int-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Check datatypes - change sqft_basement from 'o' to int</a></span></li><li><span><a href="#Dates-to-datetime" data-toc-modified-id="Dates-to-datetime-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Dates to datetime</a></span></li><li><span><a href="#Check-for-duplicates" data-toc-modified-id="Check-for-duplicates-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Check for duplicates</a></span></li><li><span><a href="#Null-Values" data-toc-modified-id="Null-Values-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Null Values</a></span><ul class="toc-item"><li><span><a href="#waterfront-and-yr_renovated-represent-11%-and-18%-of-rows.--For-waterfront,-decision-to-fill-with-zeros-assumes-sellers/buyers-would-complete-that-part-of-the-form-as-it-is-so-valuable.--Yr_renovated-is-the-same-assumption-fill-with-zeros.--Fil-all-insignificant-other-items-with-0" data-toc-modified-id="waterfront-and-yr_renovated-represent-11%-and-18%-of-rows.--For-waterfront,-decision-to-fill-with-zeros-assumes-sellers/buyers-would-complete-that-part-of-the-form-as-it-is-so-valuable.--Yr_renovated-is-the-same-assumption-fill-with-zeros.--Fil-all-insignificant-other-items-with-0-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>waterfront and yr_renovated represent 11% and 18% of rows.  For waterfront, decision to fill with zeros assumes sellers/buyers would complete that part of the form as it is so valuable.  Yr_renovated is the same assumption-fill with zeros.  Fil all insignificant other items with 0</a></span></li></ul></li><li><span><a href="#Check-for-dtypes--" data-toc-modified-id="Check-for-dtypes---6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Check for dtypes -</a></span><ul class="toc-item"><li><span><a href="#Assumed-:-drop-date,-id.--date-is-within-a-small-timeframe;-id-is-meaningless-for-this-analysis;" data-toc-modified-id="Assumed-:-drop-date,-id.--date-is-within-a-small-timeframe;-id-is-meaningless-for-this-analysis;-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Assumed : drop date, id.  date is within a small timeframe; id is meaningless for this analysis;</a></span></li></ul></li></ul></li><li><span><a href="#Exploration" data-toc-modified-id="Exploration-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Exploration</a></span><ul class="toc-item"><li><span><a href="#Observations:" data-toc-modified-id="Observations:-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Observations:</a></span></li><li><span><a href="#ID/Date-do-not-show-as-they-were-dropped" data-toc-modified-id="ID/Date-do-not-show-as-they-were-dropped-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>ID/Date do not show as they were dropped</a></span></li><li><span><a href="#Various-categorical-&amp;-continuous-data-questions." data-toc-modified-id="Various-categorical-&amp;-continuous-data-questions.-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Various categorical &amp; continuous data questions.</a></span></li></ul></li><li><span><a href="#Outliers-using-z-scores" data-toc-modified-id="Outliers-using-z-scores-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Outliers using z scores</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#small-number-of-outliers---delete-from-df-ds-and-add-to-KC_outliers_any-boolean-array" data-toc-modified-id="small-number-of-outliers---delete-from-df-ds-and-add-to-KC_outliers_any-boolean-array-8.0.1"><span class="toc-item-num">8.0.1&nbsp;&nbsp;</span>small number of outliers - delete from df ds and add to KC_outliers_any boolean array</a></span></li><li><span><a href="#looks-more-normal-with-less-outliers---but-still-some-outliers-which-we-will-keep-for-now" data-toc-modified-id="looks-more-normal-with-less-outliers---but-still-some-outliers-which-we-will-keep-for-now-8.0.2"><span class="toc-item-num">8.0.2&nbsp;&nbsp;</span>looks more normal with less outliers - but still some outliers which we will keep for now</a></span></li></ul></li><li><span><a href="#Normality-after-outliers-excluded" data-toc-modified-id="Normality-after-outliers-excluded-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Normality after outliers excluded</a></span></li><li><span><a href="#Assumprions:-homoscedasticity-and-no-multicolinearity-for-now" data-toc-modified-id="Assumprions:-homoscedasticity-and-no-multicolinearity-for-now-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Assumprions: homoscedasticity and no multicolinearity for now</a></span></li></ul></li><li><span><a href="#Multiple-linear-regression" data-toc-modified-id="Multiple-linear-regression-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Multiple linear regression</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Although-model-gave-70.4-r2,-not-a-good-fit----have-not-checked-multicolinearity-or-homoscedasticity" data-toc-modified-id="Although-model-gave-70.4-r2,-not-a-good-fit----have-not-checked-multicolinearity-or-homoscedasticity-9.0.1"><span class="toc-item-num">9.0.1&nbsp;&nbsp;</span>Although model gave 70.4 r2, not a good fit  - have not checked multicolinearity or homoscedasticity</a></span></li></ul></li></ul></li><li><span><a href="#Multicolinearity" data-toc-modified-id="Multicolinearity-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Multicolinearity</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Based-on-review-of-correlations,-drop-sqft_above" data-toc-modified-id="Based-on-review-of-correlations,-drop-sqft_above-10.0.1"><span class="toc-item-num">10.0.1&nbsp;&nbsp;</span>Based on review of correlations, drop sqft_above</a></span></li></ul></li><li><span><a href="#Revised-multicolinearity-shows-no-significant-features-are-multicolinear" data-toc-modified-id="Revised-multicolinearity-shows-no-significant-features-are-multicolinear-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Revised multicolinearity shows no significant features are multicolinear</a></span></li><li><span><a href="#Variance-Inflation-Factor---correlation" data-toc-modified-id="Variance-Inflation-Factor---correlation-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Variance Inflation Factor - correlation</a></span></li><li><span><a href="#Review-homoscedasticity" data-toc-modified-id="Review-homoscedasticity-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Review homoscedasticity</a></span></li></ul></li><li><span><a href="#Change-assumption---go-back-and-review-the-the-categories,-normalize-the-data,-rerun-the-model" data-toc-modified-id="Change-assumption---go-back-and-review-the-the-categories,-normalize-the-data,-rerun-the-model-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Change assumption - go back and review the the categories, normalize the data, rerun the model</a></span></li><li><span><a href="#Categorical-Date-for-OHE" data-toc-modified-id="Categorical-Date-for-OHE-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Categorical Date for OHE</a></span><ul class="toc-item"><li><span><a href="#Check-independence-with-Chi-Squared" data-toc-modified-id="Check-independence-with-Chi-Squared-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Check independence with Chi-Squared</a></span></li><li><span><a href="#Calculate-new-model" data-toc-modified-id="Calculate-new-model-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Calculate new model</a></span></li><li><span><a href="#Very-little-change-from-dropping-yr_renovated" data-toc-modified-id="Very-little-change-from-dropping-yr_renovated-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>Very little change from dropping yr_renovated</a></span></li><li><span><a href="#Check-value-types-for-test-item---'floors'" data-toc-modified-id="Check-value-types-for-test-item---'floors'-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>Check value types for test item - 'floors'</a></span></li><li><span><a href="#Again,-not-much-change.--Try-determining-categories-with" data-toc-modified-id="Again,-not-much-change.--Try-determining-categories-with-12.5"><span class="toc-item-num">12.5&nbsp;&nbsp;</span>Again, not much change.  Try determining categories with</a></span></li><li><span><a href="#Price-est-is-target" data-toc-modified-id="Price-est-is-target-12.6"><span class="toc-item-num">12.6&nbsp;&nbsp;</span>Price est is target</a></span></li><li><span><a href="#Bedrooms-look-c" data-toc-modified-id="Bedrooms-look-c-12.7"><span class="toc-item-num">12.7&nbsp;&nbsp;</span>Bedrooms look c</a></span></li></ul></li><li><span><a href="#Log-Transformation" data-toc-modified-id="Log-Transformation-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Log Transformation</a></span><ul class="toc-item"><li><span><a href="#Levenes-test" data-toc-modified-id="Levenes-test-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Levenes test</a></span></li></ul></li><li><span><a href="#Review-single-item-for-suitability-for-regression---sqft_living" data-toc-modified-id="Review-single-item-for-suitability-for-regression---sqft_living-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Review single item for suitability for regression - sqft_living</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#regplot-looks-like-outliers-but-data-somewhat-fits-around-the-line.--boxplot-same---looks-like-outliers-but-for-now-keep-the-data-in" data-toc-modified-id="regplot-looks-like-outliers-but-data-somewhat-fits-around-the-line.--boxplot-same---looks-like-outliers-but-for-now-keep-the-data-in-14.0.1"><span class="toc-item-num">14.0.1&nbsp;&nbsp;</span>regplot looks like outliers but data somewhat fits around the line.  boxplot same - looks like outliers but for now keep the data in</a></span></li></ul></li><li><span><a href="#Review-Normality" data-toc-modified-id="Review-Normality-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Review Normality</a></span><ul class="toc-item"><li><span><a href="#Both-are-skewed-right...again-outliers?" data-toc-modified-id="Both-are-skewed-right...again-outliers?-14.1.1"><span class="toc-item-num">14.1.1&nbsp;&nbsp;</span>Both are skewed right...again outliers?</a></span></li></ul></li></ul></li><li><span><a href="#Review-single-item-for-suitability-for-regression---sqft_living" data-toc-modified-id="Review-single-item-for-suitability-for-regression---sqft_living-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Review single item for suitability for regression - sqft_living</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#regplot-looks-like-outliers-but-data-somewhat-fits-around-the-line.--boxplot-same---looks-like-outliers-but-for-now-keep-the-data-in" data-toc-modified-id="regplot-looks-like-outliers-but-data-somewhat-fits-around-the-line.--boxplot-same---looks-like-outliers-but-for-now-keep-the-data-in-15.0.1"><span class="toc-item-num">15.0.1&nbsp;&nbsp;</span>regplot looks like outliers but data somewhat fits around the line.  boxplot same - looks like outliers but for now keep the data in</a></span></li></ul></li><li><span><a href="#Review-Normality" data-toc-modified-id="Review-Normality-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>Review Normality</a></span><ul class="toc-item"><li><span><a href="#Both-are-skewed-right...again-outliers?" data-toc-modified-id="Both-are-skewed-right...again-outliers?-15.1.1"><span class="toc-item-num">15.1.1&nbsp;&nbsp;</span>Both are skewed right...again outliers?</a></span></li></ul></li></ul></li><li><span><a href="#Single--Regression" data-toc-modified-id="Single--Regression-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Single  Regression</a></span></li></ul></div>

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Joan Leonard Short
# * Student pace: self paced / part time / full time: full-time
# * Scheduled project review date/time:
# * Instructor name: James Irving
# * Blog post URL:

# %% [markdown]
# <h2>Project Summary</h2>

# %% [markdown]
# Using the King County House Sales dataset, the client(a group of sellers) would like us to determine what factors drive the price of homes using multivariate regression analysis.  Based on the dataset we will review at least 3 meaningful questions about drivers of housing prices.

# %% [markdown]
# <h2>Mission</h2>

# %% [markdown]
# Our mission is to obtain, understand and analyze the dataset provided by the client and to use analytical, graphical and statistical means to infer house prices

# %% [markdown]
# <h2>Import packages</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
from datetime import datetime
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from scipy import stats as stats

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# <h2>Transform the data and provide high level analysis</h2>

# %%
# read-in data and create dataset df
df = pd.read_csv('/Users/owner/flatiron1/myproject2/dsc-mod-2-project-v2-1-onl01-dtsc-ft-070620/kc_house_data.csv', parse_dates=True)

# %%
# DataFrame with 21 columns of housing data and a range of17775 to 21597 non 
#null rows. Data types are objects, integers an floats

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %% [markdown]
# data from 5/21/14 to 2/25/15; housing prices from 180k to 604k; sq ft house 770 - 2570
# sq ft lot 1076 - 10000; grade 6-8?; sq ft above? 770- 2310; sq ft basement 0 - 910; yr built 1933 - 2014: yr reno only 1 1991; zip code 98027 - 98178; lat 47.510 - 47.739; lon -122.045 : -122.393; sq ft 15 houses around 1020 - 2720; sq ft 15 lot 1287 - 8062

# %%
#presentation of data
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ## Data Cleaning ##

# %% [markdown]
# ### Review column names to ensure that they represent the actual data ###

# %%
# column names - change date to date_sold, view to viewed_by_buyer
df.columns
df.rename(columns={'date':'date_sold',
                   'view':'viewed_by_buyer',
                   'price':'price_est' ,
                   'bathrooms':'baths_to_beds'},
                    inplace=True)

# %% [markdown]
# ### Check datatypes - change sqft_basement from 'o' to int

# %%
# sqft_basement change from series object to int

df['sqft_basement'] = pd.to_numeric(df['sqft_basement'], errors='coerce')
df['sqft_basement'].fillna('0', inplace=True)
df['sqft_basement'] = df['sqft_basement'].astype('int')
df['sqft_basement'] = df['sqft_basement'].astype(str).astype(int)
print(type(df['sqft_basement']))
print(df['sqft_basement'].dtype)
# Out:
# <class 'pandas.core.series.Series'>
# int64

# %% [markdown]
# ### Dates to datetime

# %%
# dates to datetime
df['date_sold'] = pd.to_datetime(df['date_sold'])
print(df.date_sold.dt)
df['date_sold'].dtype
np.dtype('datetime64[ns]') == np.dtype('<M8[ns]')
# Out:
# ...
# True

# %% [markdown]
# ### Check for duplicates ###

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date_sold, price_est, bedrooms, baths_to_beds, sqft_living, sqft_lot, floors, waterfront, viewed_by_buyer, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Null Values ###

# %%
#NAs
df_null = {}
for item in df.columns:
    df_null[item] = df[item].isnull().sum().sum()
df_null
# Out:
# {'id': 0,
#  'date_sold': 0,
#  'price_est': 0,
#  'bedrooms': 0,
#  'baths_to_beds': 0,
#  'sqft_living': 0,
#  'sqft_lot': 0,
#  'floors': 0,
#  'waterfront': 2376,
#  'viewed_by_buyer': 63,
#  'condition': 0,
#  'grade': 0,
#  'sqft_above': 0,
#  'sqft_basement': 0,
#  'yr_built': 0,
#  'yr_renovated': 3842,
#  'zipcode': 0,
#  'lat': 0,
#  'long': 0,
#  'sqft_living15': 0,
#  'sqft_lot15': 0}

# %% [markdown]
# #### waterfront and yr_renovated represent 11% and 18% of rows.  For waterfront, decision to fill with zeros assumes sellers/buyers would complete that part of the form as it is so valuable.  Yr_renovated is the same assumption-fill with zeros.  Fil all insignificant other items with 0 ####

# %%
# fill values for waterfront with 0
df[df['waterfront'].isnull()]
df['waterfront'].fillna(value=0, axis=0, inplace=True)
df[df['waterfront'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, date_sold, price_est, bedrooms, baths_to_beds, sqft_living, sqft_lot, floors, waterfront, viewed_by_buyer, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
# fill viewed_by_buyer with 0
df[df['viewed_by_buyer'].isnull()] 
print(df['viewed_by_buyer'].value_counts(dropna=False))
df['viewed_by_buyer'].fillna(value=0.0, axis=0, inplace=True)
print(df[df['viewed_by_buyer'].isnull()] )
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# NaN       63
# Name: viewed_by_buyer, dtype: int64
# Empty DataFrame
# Columns: [id, date_sold, price_est, bedrooms, baths_to_beds, sqft_living, sqft_lot, floors, waterfront, viewed_by_buyer, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Fill yr_renovated with 0
print(df['yr_renovated'].value_counts(dropna=False))
df['yr_renovated'].fillna(value=0.0, axis=0, inplace=True)
print(df[df['yr_renovated'].isnull()] )
# Out:
# 0.0       17011
# NaN        3842
# 2014.0       73
# 2003.0       31
# 2013.0       31
#           ...
# 1944.0        1
# 1948.0        1
# 1976.0        1
# 1934.0        1
# 1953.0        1
# Name: yr_renovated, Length: 71, dtype: int64
# Empty DataFrame
# Columns: [id, date_sold, price_est, bedrooms, baths_to_beds, sqft_living, sqft_lot, floors, waterfront, viewed_by_buyer, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Check for dtypes - ###

# %%
# delete datetime column and create new file to save it.
date_time_col = df['date_sold']
date_time_col
df.drop('date_sold', axis = 1, inplace= True)
df.drop('id', axis = 1, inplace= True)

df.head(2)
# Out:
#    price_est  bedrooms  baths_to_beds  sqft_living  sqft_lot  floors  \
# 0   221900.0         3           1.00         1180      5650     1.0
# 1   538000.0         3           2.25         2570      7242     2.0
#
#    waterfront  viewed_by_buyer  condition  grade  sqft_above  sqft_basement  \
# 0         0.0              0.0          3      7        1180              0
# 1         0.0              0.0          3      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955           0.0    98178  47.5112 -122.257           1340
# 1      1951        1991.0    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639

# %% [markdown]
# #### Assumed : drop date, id.  date is within a small timeframe; id is meaningless for this analysis;

# %%
df.head()
# Out:
#    price_est  bedrooms  baths_to_beds  sqft_living  sqft_lot  floors  \
# 0   221900.0         3           1.00         1180      5650     1.0
# 1   538000.0         3           2.25         2570      7242     2.0
# 2   180000.0         2           1.00          770     10000     1.0
# 3   604000.0         4           3.00         1960      5000     1.0
# 4   510000.0         3           2.00         1680      8080     1.0
#
#    waterfront  viewed_by_buyer  condition  grade  sqft_above  sqft_basement  \
# 0         0.0              0.0          3      7        1180              0
# 1         0.0              0.0          3      7        2170            400
# 2         0.0              0.0          3      6         770              0
# 3         0.0              0.0          5      7        1050            910
# 4         0.0              0.0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.shape
# Out:
# (21597, 19)

# %% [markdown]
# ## Exploration##

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['price_est', 'bedrooms', 'baths_to_beds', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'viewed_by_buyer', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#    price_est  bedrooms  baths_to_beds  sqft_living  sqft_lot  floors  \
# 0   221900.0         3           1.00         1180      5650     1.0
# 1   538000.0         3           2.25         2570      7242     2.0
# 2   180000.0         2           1.00          770     10000     1.0
# 3   604000.0         4           3.00         1960      5000     1.0
# 4   510000.0         3           2.00         1680      8080     1.0
#
#    waterfront  viewed_by_buyer  condition  grade  sqft_above  sqft_basement  \
# 0         0.0              0.0          3      7        1180              0
# 1         0.0              0.0          3      7        2170            400
# 2         0.0              0.0          3      6         770              0
# 3         0.0              0.0          5      7        1050            910
# 4         0.0              0.0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.shape
# Out:
# (21597, 19)

# %%
for item in df_columns:
    sns.jointplot(x= item, y= 'price_est', data=df, kind='reg')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations:
# ### ID/Date do not show as they were dropped
# ### Various categorical & continuous data questions.

# %%
df.head()
# Out:
#    price_est  bedrooms  baths_to_beds  sqft_living  sqft_lot  floors  \
# 0   221900.0         3           1.00         1180      5650     1.0
# 1   538000.0         3           2.25         2570      7242     2.0
# 2   180000.0         2           1.00          770     10000     1.0
# 3   604000.0         4           3.00         1960      5000     1.0
# 4   510000.0         3           2.00         1680      8080     1.0
#
#    waterfront  viewed_by_buyer  condition  grade  sqft_above  sqft_basement  \
# 0         0.0              0.0          3      7        1180              0
# 1         0.0              0.0          3      7        2170            400
# 2         0.0              0.0          3      6         770              0
# 3         0.0              0.0          5      7        1050            910
# 4         0.0              0.0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ## Outliers using z scores ##

# %%
#create function to calculate z-scores and keep those > 3 which are the 
#outliers - the minimum outliers to delete
from scipy import stats
#def outliers_z(data):
for item in df:
    z_calc = np.abs(stats.zscore(item))
    z_calc = pd.Series(z_calc, index=item.index)
print(z_calc)
# outliers_z = z_calc > 3
# return outliers
# print(outliers)
#outliers_z(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-ef2063b45dc2> in <module>
#       4 #def outliers_z(data):
#       5 for item in df:
# ----> 6     z_calc = np.abs(stats.zscore(item))
#       7     z_calc = pd.Series(z_calc, index=item.index)
#       8 print(z_calc)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py in zscore(a, axis, ddof)
#    2307     """
#    2308     a = np.asanyarray(a)
# -> 2309     mns = a.mean(axis=axis)
#    2310     sstd = a.std(axis=axis, ddof=ddof)
#    2311     if axis and mns.ndim < a.ndim:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      60
#      61     is_float16_result = False
# ---> 62     rcount = _count_reduce_items(arr, axis)
#      63     # Make this warning show up first
#      64     if rcount == 0:
#
# ...

# %%
#Find X outliers
outliers_X = outliers_z(X)
a = outliers_X.sum()
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-96a6bb3861d1> in <module>
#       1 #Find X outliers
# ----> 2 outliers_X = outliers_z(X)
#       3 a = outliers_X.sum()
#       4 print(a)
#       5
#
# NameError: name 'X' is not defined

# %%
#Find y outliers
outliers_y = outliers_z(y)
b = outliers_y.sum()
print(b)

# %% [markdown]
# #### small number of outliers - delete from df ds and add to KC_outliers_any boolean array

# %%
# Create a DataFrame of outliers X and y
all_outliers = pd.DataFrame({'X': outliers_X,
                            'y': outliers_y})
all_outliers['any'] = all_outliers.any(axis=1)

KC_outliers_any = [all_outliers['any'].copy()]
len(all_outliers['any'])
KC_outliers_any

# %%
#create an array of outlierss KC_array
KC_array = np.any(np.stack([outliers_X, outliers_y], axis=1), axis=1)
KC_array
print(len(KC_array))

# %%
#create a DataFrame out of outliers - KC_outlier_df
KC_outlier_df = df[KC_array]
KC_outlier_df
len(KC_outlier_df)
display(KC_outlier_df)

# %%
#KC_clea
KC_clean = df[~KC_array]
print(len(KC_clean))
display(KC_clean)
KC_clean.shape

# %%
# create clean X, y of the ds remaining after outliers removes
clean_X = X[~KC_array].copy()
clean_y = y[~KC_array].copy()
print(len(clean_X))
print(len(clean_y))

# %%
# Review reg/box plots again
box_reg(clean_X, clean_y)

# %% [markdown]
# #### looks more normal with less outliers - but still some outliers which we will keep for now

# %% [markdown]
# ### Normality after outliers excluded ###

# %%
# check normality - p-values still 0.0?
normal_Xy(clean_X, clean_y)

# %%
KC_clean.shape

# %% [markdown]
# ### Assumprions: homoscedasticity and no multicolinearity for now###

# %% [markdown]
# ## Multiple linear regression ###

# %%
# formula based regression
import statsmodels.formula.api as smf
df = KC_clean.copy()
df.head(2)

# %%
pd.plotting.scatter_matrix(df)
plt.show()

# %%
#add constant
from statsmodels.regression.linear_model import OLS
df = sm.add_constant(df)
display(df.head(2))

# %%
df.shape

# %%
# Concat column names
df.drop('price_est', axis =1)
f = list(df.drop('price_est', axis =1).columns)
f = '+'.join(f)
f

# %%
#Create formula
formula= 'price_est~' + f
formula

# %%
model = smf.ols(formula, df).fit()
model.summary()

# %% [markdown]
# #### Although model gave 70.4 r2, not a good fit  - have not checked multicolinearity or homoscedasticity ####

# %%
df.head()

# %% [markdown]
# ## Multicolinearity

# %%
df['sqft_living'].value_counts

# %%
# Looks like still have categorical data and colinearity
pd.plotting.scatter_matrix(df)
plt.show()

# %%
#get correlation matrix
corr = df.corr()
mask = np.zeros_like(corr)
mask

# %%
mask[np.triu_indices_from(mask)] = True
mask

# %%
corr = df.corr()
corr

# %%
a = abs(corr) > 0.75
a

# %%
fig, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(corr, annot=True, cmap='Blues', mask=mask, ax=ax)

# %% [markdown]
# #### Based on review of correlations, drop sqft_above

# %%
df.drop(['sqft_above'], axis=1, inplace=True)

# %%
df.shape

# %%
#get correlation matrix
corr = df.corr()
mask = np.zeros_like(corr)
mask

# %%
mask[np.triu_indices_from(mask)] = True
mask

# %%
corr = df.corr()
corr

# %%
a = abs(corr) > 0.75
a

# %%
fig, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(corr, annot=True, cmap='Blues', mask=mask, ax=ax)

# %%
df_corr=corr.abs().stack().reset_index().sort_values(0, ascending=False)
df_corr

# %%
df_corr['pairs'] = list(zip(df_corr['level_0'], df_corr['level_1']))

df_corr.set_index(['pairs'], inplace = True)
df_corr.drop(columns=['level_1', 'level_0'], inplace = True)

# %%
df_corr.columns = ['cc']
df_corr = df_corr['cc'].sort_values(ascending=True)
df_corr

# %%
df_corr.drop_duplicates(inplace=True)
df_corr

# %%
(df_corr > 0.75) &  (df_corr < 1)

# %%
# Heat map shows not much correlation except sqft_living and sqft_above
fig, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(corr, annot=True, cmap='Blues', mask=mask, ax=ax)

# %% [markdown]
# ### Revised multicolinearity shows no significant features are multicolinear

# %% [markdown]
# ### Variance Inflation Factor - correlation

# %%
df.head()

# %%
df.shape

# %%
df_columns = df.columns

# %%
# Run the model
df_columns.drop(['price_est', 'target'], axis=1, inplace=True)
# features = '+'.join(df_columns)
# features
df_columns

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import patsy
# get y and X dataframes based on this regression:
y, X = patsy.dmatrices('price_est ~' + features, data=df, return_type='dataframe')
X

# %%
#calculate VIF
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)

# %% [markdown]
# ### Review homoscedasticity

# %%
import scipy.stats as stats

resid = model.resid 
sm.graphics.qqplot(resid,stats.norm,line='45',fit=True)

# %% [markdown]
# ## Change assumption - go back and review the the categories, normalize the data, rerun the model

# %% [markdown]
# ## Categorical Date for OHE

# %%
df.columns

# %% [markdown]
# ### Check independence with Chi-Squared

# %%
crosstab = pd.crosstab(df['price_est'], df['zipcode'])


crosstab

# %%
stats.chi2_contingency(crosstab)

# %% [markdown]
# 'bedrooms'
#         32408.449019255197,
# p-value 1.0,
#         38368,
# 'floors',
#         17755.259362638048,
# p-value 0.046330275361922,
#         17440,
#
# 'waterfront',
#                                         2043.0994715176748,
# p-value  1.0,
#          3488,
#
# 'viewed_by_buyer',
#          13616.464334763448,
# p-value  0.9783595206635082,
#          13952,
# 'condition',
#          15931.345473638417,
#          4.400207949980283e-30,
#          13952,
# 'grade',
#          43010.94512296419,
#          0.0,
#          31392,
#
# 'yr_built'
#         389739.20873923984,
#         1.0,
#         401120,
#
# 'yr_renovated',
#         264943.61942319863,
#          8.124322573888866e-252,
#          240672,
#
# 'zipcode'
#         254586.66107907798,
#         1.5081731136073052e-86,
#         240672,

# %%
df['yr_renovated'].value_counts()

# %% [markdown]
# ####Conclusion - drop year_renovated with 8.1 pvalue

# %%
df.drop(['yr_renovated'], axis=1, inplace=True)

# %%
df.head()

# %% [markdown]
# ### Calculate new model

# %%
def model_in():
    f = []
    # concat column names
    df.drop('price_est', axis =1)
df.head()

# %%
f = list(df.drop('price_est', axis =1).columns)
f = '+'.join(f)
    #create formula
formula= 'price_est~' + f

print(f)

# %%
model_in()

# %%
df.shape

# %%
model = model_out(formula, df)
fig = sm.graphics.qqplot(model.resid, dist=stats.norm,fit=True, line='45')

# %% [markdown]
# ### Very little change from dropping yr_renovated

# %% [markdown]
# ### Check value types for test item - 'floors'

# %%
df['floors'].value_counts()

# %%
floors_category = df['floors'].astype('category')
floors_category

# %%
coded_floors = floors_category.cat.codes
coded_floors

# %%
pd.get_dummies(floors_category, drop_first=False)

# %%
model_df = df.copy()
model_df

# %%
## Dummy Encode categorical vars
model_df = pd.get_dummies(model_df,columns=['bedrooms', 'floors', 'waterfront', 'viewed_by_buyer', 'condition', 'grade', 'yr_built', 'zipcode'],drop_first=True)
model_df

# %%
model_df.shape

# %%
df.columns

# %%
c_cols = ['bedrooms', 'floors', 'waterfront', 'viewed_by_buyer', 'condition', 'grade', 'yr_built', 'zipcode']
num_cols = ['baths_to_beds', 'sqft_living', 'sqft_lot', 'sqft_basement', 'lat', 'long', 'sqft_living', 'sqft_living15', 'sqft_lot15']
cat_col_list = '+'.join(c_cols)
num_cols_list = '+'.join(num_cols)
formula = "price_est~"+cat_col_list+'+'+num_cols_list
formula

# %%
model_in()

# %%
df.head()

# %%
model = formula, df
fig = sm.graphics.qqplot(model.resid, dist=stats.norm,fit=True, line='45')

# %% [markdown]
# ### Again, not much change.  Try determining categories with

# %%
## Inspect the Value Counts for Each Str Col
for col in c_cols:
    display(df[col].value_counts(dropna=False))
    print()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[num_cols])
scaled_data.shape

# %%
type(scaled_data), scaled_data.shape

# %%
df_scaled = pd.DataFrame(data=scaled_data,columns=num_cols)
df_scaled.describe().round(3)

# %%
df_scaled['price_est'] = df['price_est']
#df_scaled['chas'] = boston['chas']
df_scaled.describe().round(3)

# %%
c_cols = ['bedrooms', 'floors', 'waterfront', 'viewed_by_buyer', 'condition', 'grade', 'yr_built', 'zipcode']
for item in c_cols:
    df_scaled += df[item]

# %%
from __future__ import print_function
ts import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
num_cols = df.columns
#from ipywidgets 
import interact

# @interact
# def show_plot(col=num_cols):
# # for col in num_cols:
#     plot_col(df,col)

# %% [markdown]
# ### Price est is target ###
# ### Bedrooms look c

# %% [markdown]
# ## Log Transformation

# %%
model.params

# %%
## Calcualte y_hat using the model's coefficients 
y_hat = 107.13 * X_clean.iloc[:,1] +1.857e+04 
y_hat

# %%
## Calcualte y_hat using the model's coefficients 
y_hat = 107.13 * X_clean.iloc[:,1] +1.857e+04 
y_hat

# %%
#create an array of outlierss KC_array
df_array = np.any(np.stack([outliers_X, outliers_y], axis=1), axis=1)
df_array
print(len(df_array))

# %%
plt.scatter(Xo, yo)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Review of Outliers')
mean_y = y.mean()

plt.axhline(y=int(mean_y))

# %%
# Outliers + clean ds = original ds
print(len(KC_outlier_df['sqft_living']))
len(KC_clean['sqft_living'])

# %%
all_col = df[cols].copy()

# %%
all_col.info()

# %%
all_col.describe()

# %%
features = '+'.join(all_col)
features

# %%
model = smf.ols(f, )

f = features
ds = df_clean
model_out(f, ds)

def model_out(f, ds):
    f = f
    model = smf.ols(f, ds).fit()
    display(model.summary())
f = 'price_est~sqft_living'
ds = df_clean
model_out(f, ds)

# %% [markdown]
# ### Levenes test

# %%
import scipy.stats as st

## Make list of list of headers
results = [['Group','n','Normaltest Stat','p','sig?']]

## Make an empty list for our group data
test_equal_var = []

## Loop through the data dictionary 
for grp,grp_df in data.items():
   
    ## Grab the correct phase column from the group df
    grp_data = grp_df[test_phase].copy()
    ## Append group data to list of group data
    test_equal_var.append(grp_data)
    
    ## Test for nomrality and save result 
    stat,p = st.normaltest(grp_data)
    results.append([grp,len(grp_data),stat,p,p<.05])


## Test for equal variance
stat, p = st.levene(*test_equal_var)
results.append(['Equal Variance','all',stat,p,p<.05])
    
results_df = pd.DataFrame(results[1:],columns=results[0])
results_df

# %% [markdown]
# ## Review single item for suitability for regression - sqft_living

# %%
### Review Linearity

# %%
X = df['sqft_living'].copy()
y = df['price_est'].copy()

# %%
# create reg & boxplots to visualize X, y relationship
def box_reg(X, y):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize = (15,5))
    sns.regplot(X, y, ax=ax1, line_kws= {'color' : 'r', 'ls' : ':'})
    ax2 = sns.boxplot(y)
    q3 = np.quantile(y, .75)
    q1 = np.quantile(y, .25)
    IQR = q3 - q1
    ax2.axvline(q3)
box_reg(X, y)

# %% [markdown]
# #### regplot looks like outliers but data somewhat fits around the line.  boxplot same - looks like outliers but for now keep the data in

# %% [markdown]
# ### Review Normality ###

# %%
# Check against normal distribution - both skew right
# P-value = 0.0 meaning that it is impossible for the sample to be part of 
#a normal distribution?
def normal_Xy(X, y):
    fig, axes = plt.subplots(ncols=2, figsize=(10,5))
                             
    sns.distplot(X, ax=axes[0], kde=False, bins = 'auto')
    axes[0].set(xlabel= 'X')
    sns.distplot(y, ax=axes[1], kde=False, bins='auto', color='r')
    axes[1].set(xlabel= 'y')
    print("X Normality: ",stats.normaltest(X))
    print("y Normalty: ",stats.normaltest(y))
    return fig, axes
normal_Xy(X, y)

# %% [markdown]
# #### Both are skewed right...again outliers? ####

# %% [markdown]
# ## Review single item for suitability for regression - sqft_living

# %%
### Review Linearity

# %%
X = df['sqft_living'].copy()
y = df['price_est'].copy()

# %%
# create reg & boxplots to visualize X, y relationship
def box_reg(X, y):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize = (15,5))
    sns.regplot(X, y, ax=ax1, line_kws= {'color' : 'r', 'ls' : ':'})
    ax2 = sns.boxplot(y)
    q3 = np.quantile(y, .75)
    q1 = np.quantile(y, .25)
    IQR = q3 - q1
    ax2.axvline(q3)
box_reg(X, y)

# %% [markdown]
# #### regplot looks like outliers but data somewhat fits around the line.  boxplot same - looks like outliers but for now keep the data in

# %% [markdown]
# ### Review Normality ###

# %%
# Check against normal distribution - both skew right
# P-value = 0.0 meaning that it is impossible for the sample to be part of 
#a normal distribution?
def normal_Xy(X, y):
    fig, axes = plt.subplots(ncols=2, figsize=(10,5))
                             
    sns.distplot(X, ax=axes[0], kde=False, bins = 'auto')
    axes[0].set(xlabel= 'X')
    sns.distplot(y, ax=axes[1], kde=False, bins='auto', color='r')
    axes[1].set(xlabel= 'y')
    print("X Normality: ",stats.normaltest(X))
    print("y Normalty: ",stats.normaltest(y))
    return fig, axes
normal_Xy(X, y)

# %% [markdown]
# #### Both are skewed right...again outliers? ####

# %% [markdown]
# ## Single  Regression  ##

# %%
target = KC_clean['price_est'].copy()

# %%
predictor = KC_clean['sqft_living'].copy()

# %%
#add constant
from statsmodels.regression.linear_model import OLS
predictor = sm.add_constant(predictor)
display(predictor)

# %%
#create regression model
model = OLS(target, predictor,hasconst = True).fit()
model.summary()


## Get y_pred and equation for plot
#

# %%
#QQ plot says not a good fit
fig = sm.graphics.qqplot(model.resid, dist=stats.norm,fit=True, line='45')

# %%
fig=sm.graphics.plot_regress_exog(model, 'sqft_living', fig=plt.figure(figsize = (15,10)))

# %%
def qq_regress(title, col):
    f = title
    ax2 = sm.graphics.plot_regress_exog(model, col, fig=plt.figure(figsize = (15,10)))
qq_regress('KC Est_price vs Sqft_living', 'sqft_living')

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Final Project Submission</a></span></li><li><span><a href="#Project-Summary" data-toc-modified-id="Project-Summary-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project Summary</a></span></li><li><span><a href="#Mission" data-toc-modified-id="Mission-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Mission</a></span></li><li><span><a href="#Import-packages" data-toc-modified-id="Import-packages-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import packages</a></span></li><li><span><a href="#Transform-the-data-and-provide-high-level-analysis" data-toc-modified-id="Transform-the-data-and-provide-high-level-analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Transform the data and provide high level analysis</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Null-Values" data-toc-modified-id="Null-Values-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Null Values</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Outliers</a></span></li></ul></li></ul></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Final Project Submission</a></span></li><li><span><a href="#Project-Summary" data-toc-modified-id="Project-Summary-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project Summary</a></span></li><li><span><a href="#Mission" data-toc-modified-id="Mission-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Mission</a></span></li><li><span><a href="#Import-packages" data-toc-modified-id="Import-packages-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import packages</a></span></li><li><span><a href="#Transform-the-data-and-provide-high-level-analysis" data-toc-modified-id="Transform-the-data-and-provide-high-level-analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Transform the data and provide high level analysis</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Review-column-names-to-ensure-that-they-represent-the-actual-data" data-toc-modified-id="Review-column-names-to-ensure-that-they-represent-the-actual-data-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Review column names to ensure that they represent the actual data</a></span></li><li><span><a href="#Dates-to-datetime" data-toc-modified-id="Dates-to-datetime-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Dates to datetime</a></span></li><li><span><a href="#Null-Values" data-toc-modified-id="Null-Values-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Null Values</a></span></li><li><span><a href="#Calculate-#-of-Bathrooms" data-toc-modified-id="Calculate-#-of-Bathrooms-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Calculate # of Bathrooms</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Outliers</a></span></li><li><span><a href="#Based-on-review-for-outliers,-selected-the-following-columns-for-review:" data-toc-modified-id="Based-on-review-for-outliers,-selected-the-following-columns-for-review:-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Based on review for outliers, selected the following columns for review:</a></span><ul class="toc-item"><li><span><a href="#price_est,-bedrooms,-bathrooms,-bed_to_bath,-sqft_above,-lat,-long,-sqft_living_15,-sqft_basement" data-toc-modified-id="price_est,-bedrooms,-bathrooms,-bed_to_bath,-sqft_above,-lat,-long,-sqft_living_15,-sqft_basement-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>price_est, bedrooms, bathrooms, bed_to_bath, sqft_above, lat, long, sqft_living_15, sqft_basement</a></span></li><li><span><a href="#Sales" data-toc-modified-id="Sales-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>Sales</a></span></li></ul></li></ul></li><li><span><a href="#Analysis" data-toc-modified-id="Analysis-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Analysis</a></span></li></ul></div>
